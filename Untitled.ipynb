# %%
import os
import io
os.chdir('C:\\Users\\jeanl\\Desktop')
os.getcwd()
# Out:
# 'C:\\Users\\jeanl\\Desktop'

# %%
# 1

# %%
import gzip

a_file = gzip.open("migr_asydcfsta_linear.csv.gz", "rb")
contents = a_file.read()

print(contents)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
# 2

# %%
with gzip.open("migr_asydcfsta_linear.csv.gz", 'rb') as ip:
        with io.TextIOWrapper(ip, encoding='utf-8') as decoder:
            # Let's read the content using read()
            content = decoder.read()
            print(content)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
# 3

# %%
f = gzip.open(path+myFile, 'r')
for line in f:
    #(yadda yadda)
f.close()

# %%
for line in f:
